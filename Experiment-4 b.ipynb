# %%
# importing libraries

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
# Step 1: Load the Digits dataset
digits = load_digits()

# Features (64 pixel values) and target (digit labels)
X = digits.data
y = digits.target

print("Original Shape:", X.shape)
# Out:
# Original Shape: (1797, 64)

# %%
# Step 2: Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Step 3: Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Reduced Shape:", X_pca.shape)
# Out:
# Reduced Shape: (1797, 2)

# %%
# Step 4: Explained Variance Ratio
print("Explained Variance Ratio:")
print(pca.explained_variance_ratio_)

print("Total Variance Explained:",
      np.sum(pca.explained_variance_ratio_))
# Out:
# Explained Variance Ratio:
# [0.12033916 0.09561054]
# Total Variance Explained: 0.21594970500832789

# %%
# Step 5: Eigenvalues
print("\nEigenvalues:")
print(pca.explained_variance_)
# Out:
# Eigenvalues:
# [7.34477606 5.83549054]

# %%
# Step 6: Eigenvectors
print("\nEigenvectors:")
print(pca.components_)
# Out:
# Eigenvectors:
# [[-0.          0.18223392  0.285868    0.22036967 -0.02516956 -0.00949725
#   -0.0524765  -0.06269499  0.03470727  0.24553368  0.22915174 -0.10794381
#    0.03620209  0.03871159 -0.08378077 -0.09277502  0.01669934  0.1367165
#   -0.06305075 -0.12287927  0.14819348 -0.02348425 -0.1711997  -0.10420837
#   -0.00394882 -0.1163897  -0.18820473  0.0658604   0.14353257 -0.12820705
#   -0.18062075 -0.05270917 -0.         -0.23890251 -0.23500613 -0.00509137
#   -0.01310881 -0.15911618 -0.12939416 -0.         -0.05559906 -0.18715707
#   -0.15353371 -0.04682572 -0.11089272 -0.10720947  0.01792652 -0.00227271
#   -0.02881729  0.040868    0.11027068  0.0318244  -0.07904945  0.06832147
#    0.12124707  0.04877119 -0.00183586  0.16039569  0.27985301  0.19444929
#    0.01777381  0.103198    0.1198106   0.07149362]
#  [ 0.          0.04702701  0.0595648  -0.02080385  0.15590316  0.27413299
#    0.24973251  0.14583207 -0.00102721  0.02761909  0.01450474 -0.09225537
#    0.0572917   0.21410852  0.26653585  0.13699943 -0.00733687 -0.02014035
#   -0.11844133 -0.08408699  0.07684584  0.15949153  0.14605982  0.08083712
#   -0.00388437 -0.06552741 -0.11263765  0.05368068  0.16490377  0.13773838
#    0.056104    0.02670685  0.         -0.11768141 -0.10539516  0.05889428
#    0.11611027 -0.0052107  -0.07934642  0.         -0.02367678 -0.10434601
#   -0.18915365  0.00912699  0.14888589 -0.0907634  -0.24058321 -0.07869055
#   -0.01004025 -0.03527397 -0.18560853 -0.03953018  0.06234747 -0.19312254
#   -0.25775152 -0.11500205  0.00488251  0.04449786  0.08139985 -0.0099049
#   -0.25193395 -0.24261778 -0.16508926 -0.07132924]]

# %%
# Step 7: Scatter Plot
plt.figure(figsize=(8,6))

scatter = plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=y,
    cmap='viridis'
)

plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA on Digits Dataset")
plt.colorbar(scatter, label="Digit")
plt.show()
